# %% [markdown]
# <a href="https://colab.research.google.com/github/HernandezDylan/UIII-Act-9-Proyecto-de-simulaci-n-de-inteligencia-artificial-Hernadz-Dylan1245/blob/main/UIII_Act_9_Proyecto_de_simulaci%C3%B3n_de_inteligencia_artificial_Hernandez_Dylan_1245.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Hernadez Dylan FECHA 25/05/2026 NL = 28
#
# #### Analista

# %%
# Lista vacía
lista  = []

while True:

    print("\n====== MENU ======")
    print("1. Agregar comida")
    print("2. Ver menu")
    print("3. Buscar comida")
    print("4. Eliminar comida")
    print("5. Contar comidas")
    print("6. Limpiar menu")
    print("7. Salir")

    op = input("Selecciona una opcion: ")

    if op == "1":

        comida = input("Escribe una comida: ")

        menu.append(comida)

        print("Comida agregada")

    elif op == "2":

        if menu == []:

            print("El menu esta vacio")

        else:

            print("Menu guardado:")

            i = 0

            while i < len(menu):

                print("-", menu[i])

                i += 1

    elif op == "3":

        buscar = input("Comida a buscar: ")

        if buscar in menu:

            print("La comida si existe")

        else:

            print("La comida no existe")

    elif op == "4":

        eliminar = input("Comida a eliminar: ")

        if eliminar in menu:

            menu.remove(eliminar)

            print("Comida eliminada")

        else:

            print("Esa comida no existe")

    elif op == "5":

        print("Total de comidas:", len(menu))

    elif op == "6":

        menu = []

        print("Menu limpio")

    elif op == "7":

        print("Programa terminado")

        break

    else:

        print("Opcion incorrecta")
# Out:
# ====== MENU ======
# 1. Agregar comida
# 2. Ver menu
# 3. Buscar comida
# 4. Eliminar comida
# 5. Contar comidas
# 6. Limpiar menu
# 7. Salir
# Selecciona una opcion: 1
# Escribe una comida: Bonneles
# Comida agregada
#
# ====== MENU ======
# 1. Agregar comida
# 2. Ver menu
# 3. Buscar comida
# 4. Eliminar comida
# 5. Contar comidas
# 6. Limpiar menu
# 7. Salir
# Selecciona una opcion: 1
# Escribe una comida: Sushi
# Comida agregada
#
# ====== MENU ======
# 1. Agregar comida
# 2. Ver menu
# 3. Buscar comida
# 4. Eliminar comida
# 5. Contar comidas
# 6. Limpiar menu
# 7. Salir
# Selecciona una opcion: 1
# Escribe una comida: Sopa
# Comida agregada
#
# ====== MENU ======
# 1. Agregar comida
# 2. Ver menu
# 3. Buscar comida
# 4. Eliminar comida
# 5. Contar comidas
# 6. Limpiar menu
# 7. Salir
# Selecciona una opcion: 1
# Escribe una comida: Papas
# Comida agregada
#
# ====== MENU ======
# 1. Agregar comida
# 2. Ver menu
# 3. Buscar comida
# 4. Eliminar comida
# 5. Contar comidas
# ...

# %% [markdown]
# <img src="https://raw.githubusercontent.com/HernandezDylan/UIII-Act-9-Proyecto-de-simulaci-n-de-inteligencia-artificial-Hernadz-Dylan1245/refs/heads/main/analista%20ACT%209.png">
